# %%
import pandas as pd

# %%
df = pd.read_csv('avengers.csv')
df
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                       Name/Alias  Appearances Current?  Gender  \
# 0      Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                 Janet van Dyne         1165      YES  FEMALE
# 2    Anthony Edward "Tony" Stark         3068      YES    MALE
# ...

# %%
from matplotlib import pyplot as plt

# %%
df.drop([0,1]).hist()
plt.show()

# %%
mas_de_2000 = df[df['Appearances']>2000]
mas_de_2000
# Out:
#                                                   URL  \
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 40  http://marvel.wikia.com/Benjamin_Grimm_(Earth-...
# 57  http://marvel.wikia.com/Reed_Richards_(Earth-6...
# 73  http://marvel.wikia.com/Peter_Parker_(Earth-616)#
# 92  http://marvel.wikia.com/James_Howlett_(Earth-6...
#
#                      Name/Alias  Appearances Current? Gender  \
# 2   Anthony Edward "Tony" Stark         3068      YES   MALE
# 3           Robert Bruce Banner         2089      YES   MALE
# 4                  Thor Odinson         2402      YES   MALE
# 6                 Steven Rogers         3458      YES   MALE
# 40         Benjamin Jacob Grimm         2305       NO   MALE
# 57                Reed Richards         2125      YES   MALE
# ...

# %%
# %matplotlib inline
df[['Appearances','Years since joining']].plot.hist(bins=7,alpha=0.5)
plt.show()

# %%
df = pd.DataFrame(data={"Name/Alias":['Thor Odinson','Steven Rodgers','Peter Benjamin Parker','Anthony Edward "Tony" Stark'],
                       "Appearances":[2402,3458,4333,3068]})
df
# Out:
#                     Name/Alias  Appearances
# 0                 Thor Odinson         2402
# 1               Steven Rodgers         3458
# 2        Peter Benjamin Parker         4333
# 3  Anthony Edward "Tony" Stark         3068

# %%
df.set_index('Name/Alias')['Appearances'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Name/Alias'>

# %%
df.set_index('Name/Alias')['Appearances'].plot.pie();

# %%
df = pd.read_csv('avengers.csv')
df.corr(method= 'pearson')
# Out:
#                      Appearances      Year  Years since joining
# Appearances             1.000000 -0.067292             0.067292
# Year                   -0.067292  1.000000            -1.000000
# Years since joining     0.067292 -1.000000             1.000000

# %%
import seaborn as sb
import numpy as np; np.random.seed(0)
from matplotlib import cm
df = pd.DataFrame(data={"Appearances":[2402,3458,4333,3068],
                       "Years":[1963,1964,1990,1963],
                       "Years since joining":[52,51,25,52]})
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, 
           cmap=colormap, linecolor='white', annot=True);

# %%
import seaborn as sb
import numpy as np; np.random.seed(0)
from matplotlib import cm
sb.set_theme(style="whitegrid")
avengers= pd.DataFrame(data={"Appearances":[2402,3458,4333,3068],
                       "Years":[1963,1964,1990,1963],
                       "Years since joining":[52,51,25,52]})
ax = sb.boxplot(x=avengers["Appearances"])

# %%
plt.figure(figsize=(12,12))
ax = sb.boxplot(x="Years", y="Appearances", data=avengers)
